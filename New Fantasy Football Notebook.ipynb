# %%
#import dependencies
import pandas as pd
import requests
import time
import json
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func,inspect

# %%
#Pull full dataset from Fantasy API and in json pretty format

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/FantasyPlayers?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
print(json.dumps(response,indent=1))
# Out:
# [
#  {
#   "FantasyPlayerKey": "18877",
#   "PlayerID": 18877,
#   "Name": "Christian McCaffrey",
#   "Team": "CAR",
#   "Position": "RB",
#   "AverageDraftPosition": 1.7,
#   "AverageDraftPositionPPR": 1.7,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 82.8,
#   "ProjectedFantasyPoints": 308.7,
#   "AuctionValue": 76,
#   "AuctionValuePPR": 77,
#   "AverageDraftPositionIDP": 4,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18872",
#   "PlayerID": 18872,
#   "Name": "Dalvin Cook",
#   "Team": "MIN",
#   "Position": "RB",
#   "AverageDraftPosition": 3.2,
#   "AverageDraftPositionPPR": 3.2,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 331.4,
#   "ProjectedFantasyPoints": 298.0,
#   "AuctionValue": 71,
#   "AuctionValuePPR": 70,
#   "AverageDraftPositionIDP": 19,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "17959",
#   "PlayerID": 17959,
#   "Name": "Derrick Henry",
#   "Team": "TEN",
#   "Position": "RB",
#   "AverageDraftPosition": 3.4,
#   "AverageDraftPositionPPR": 4.6,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 354.3,
#   "ProjectedFantasyPoints": 303.9,
#   "AuctionValue": 71,
#   "AuctionValuePPR": 62,
#   "AverageDraftPositionIDP": 46,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18878",
#   "PlayerID": 18878,
#   "Name": "Alvin Kamara",
#   "Team": "NO",
#   "Position": "RB",
#   "AverageDraftPosition": 5.5,
#   "AverageDraftPositionPPR": 5.3,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 332.5,
#   "ProjectedFantasyPoints": 246.7,
#   "AuctionValue": 59,
#   "AuctionValuePPR": 60,
#   "AverageDraftPositionIDP": 3,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "17923",
#   "PlayerID": 17923,
#   "Name": "Ezekiel Elliott",
#   "Team": "DAL",
#   "Position": "RB",
#   "AverageDraftPosition": 6.6,
#   "AverageDraftPositionPPR": 6.9,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 193.7,
#   "ProjectedFantasyPoints": 254.4,
#   "AuctionValue": 59,
#   "AuctionValuePPR": 58,
#   "AverageDraftPositionIDP": 8,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19766",
#   "PlayerID": 19766,
#   "Name": "Saquon Barkley",
#   "Team": "NYG",
#   "Position": "RB",
#   "AverageDraftPosition": 7.9,
#   "AverageDraftPositionPPR": 8.0,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 10.6,
#   "ProjectedFantasyPoints": 251.3,
#   "AuctionValue": 60,
#   "AuctionValuePPR": 58,
#   "AverageDraftPositionIDP": 3,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19798",
#   "PlayerID": 19798,
#   "Name": "Nick Chubb",
#   "Team": "CLE",
#   "Position": "RB",
#   "AverageDraftPosition": 8.8,
#   "AverageDraftPositionPPR": 9.3,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 216.2,
#   "ProjectedFantasyPoints": 260.6,
#   "AuctionValue": 59,
#   "AuctionValuePPR": 51,
#   "AverageDraftPositionIDP": 20,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21682",
#   "PlayerID": 21682,
#   "Name": "Jonathan Taylor",
#   "Team": "IND",
#   "Position": "RB",
#   "AverageDraftPosition": 9.0,
#   "AverageDraftPositionPPR": 9.8,
#   "ByeWeek": 14,
#   "LastSeasonFantasyPoints": 244.6,
#   "ProjectedFantasyPoints": 261.4,
#   "AuctionValue": 62,
#   "AuctionValuePPR": 56,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18082",
#   "PlayerID": 18082,
#   "Name": "Tyreek Hill",
#   "Team": "KC",
#   "Position": "WR",
#   "AverageDraftPosition": 10.2,
#   "AverageDraftPositionPPR": 10.8,
#   "ByeWeek": 12,
#   "LastSeasonFantasyPoints": 272.9,
#   "ProjectedFantasyPoints": 241.4,
#   "AuctionValue": 55,
#   "AuctionValuePPR": 55,
#   "AverageDraftPositionIDP": 17,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "15048",
#   "PlayerID": 15048,
#   "Name": "Travis Kelce",
#   "Team": "KC",
#   "Position": "TE",
#   "AverageDraftPosition": 11.1,
#   "AverageDraftPositionPPR": 10.9,
#   "ByeWeek": 12,
#   "LastSeasonFantasyPoints": 234.4,
#   "ProjectedFantasyPoints": 216.0,
#   "AuctionValue": 55,
#   "AuctionValuePPR": 50,
#   "AverageDraftPositionIDP": 20,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19045",
#   "PlayerID": 19045,
#   "Name": "Aaron Jones",
#   "Team": "GB",
#   "Position": "RB",
#   "AverageDraftPosition": 12.1,
#   "AverageDraftPositionPPR": 14.1,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 239.0,
#   "ProjectedFantasyPoints": 241.0,
#   "AuctionValue": 52,
#   "AuctionValuePPR": 47,
#   "AverageDraftPositionIDP": 36,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21688",
#   "PlayerID": 21688,
#   "Name": "Cam Akers",
#   "Team": "LAR",
#   "Position": "RB",
#   "AverageDraftPosition": 12.5,
#   "AverageDraftPositionPPR": 15.9,
#   "ByeWeek": 11,
#   "LastSeasonFantasyPoints": 102.4,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 52,
#   "AuctionValuePPR": 46,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16470",
#   "PlayerID": 16470,
#   "Name": "Davante Adams",
#   "Team": "GB",
#   "Position": "WR",
#   "AverageDraftPosition": 14.7,
#   "AverageDraftPositionPPR": 15.2,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 274.6,
#   "ProjectedFantasyPoints": 222.3,
#   "AuctionValue": 47,
#   "AuctionValuePPR": 47,
#   "AverageDraftPositionIDP": 10,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19562",
#   "PlayerID": 19562,
#   "Name": "Austin Ekeler",
#   "Team": "LAC",
#   "Position": "RB",
#   "AverageDraftPosition": 15.7,
#   "AverageDraftPositionPPR": 11.7,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 125.5,
#   "ProjectedFantasyPoints": 209.5,
#   "AuctionValue": 43,
#   "AuctionValuePPR": 43,
#   "AverageDraftPositionIDP": 92,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16906",
#   "PlayerID": 16906,
#   "Name": "Stefon Diggs",
#   "Team": "BUF",
#   "Position": "WR",
#   "AverageDraftPosition": 15.8,
#   "AverageDraftPositionPPR": 13.6,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 227.4,
#   "ProjectedFantasyPoints": 193.5,
#   "AuctionValue": 45,
#   "AuctionValuePPR": 44,
#   "AverageDraftPositionIDP": 34,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18890",
#   "PlayerID": 18890,
#   "Name": "Patrick Mahomes",
#   "Team": "KC",
#   "Position": "QB",
#   "AverageDraftPosition": 16.1,
#   "AverageDraftPositionPPR": 24.5,
#   "ByeWeek": 12,
#   "LastSeasonFantasyPoints": 422.3,
#   "ProjectedFantasyPoints": 449.0,
#   "AuctionValue": 32,
#   "AuctionValuePPR": 30,
#   "AverageDraftPositionIDP": 18,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21861",
#   "PlayerID": 21861,
#   "Name": "Antonio Gibson",
#   "Team": "WAS",
#   "Position": "RB",
#   "AverageDraftPosition": 16.7,
#   "AverageDraftPositionPPR": 19.2,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 187.5,
#   "ProjectedFantasyPoints": 227.8,
#   "AuctionValue": 46,
#   "AuctionValuePPR": 44,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20875",
#   "PlayerID": 20875,
#   "Name": "DK Metcalf",
#   "Team": "SEA",
#   "Position": "WR",
#   "AverageDraftPosition": 19.6,
#   "AverageDraftPositionPPR": 23.3,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 212.4,
#   "ProjectedFantasyPoints": 214.8,
#   "AuctionValue": 43,
#   "AuctionValuePPR": 42,
#   "AverageDraftPositionIDP": 159,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21768",
#   "PlayerID": 21768,
#   "Name": "Najee Harris",
#   "Team": "PIT",
#   "Position": "RB",
#   "AverageDraftPosition": 19.9,
#   "AverageDraftPositionPPR": 18.0,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 228.2,
#   "AuctionValue": 45,
#   "AuctionValuePPR": 45,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18858",
#   "PlayerID": 18858,
#   "Name": "Joe Mixon",
#   "Team": "CIN",
#   "Position": "RB",
#   "AverageDraftPosition": 20.2,
#   "AverageDraftPositionPPR": 21.0,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 88.7,
#   "ProjectedFantasyPoints": 225.3,
#   "AuctionValue": 45,
#   "AuctionValuePPR": 42,
#   "AverageDraftPositionIDP": 24,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "14986",
#   "PlayerID": 14986,
#   "Name": "DeAndre Hopkins",
#   "Team": "ARI",
#   "Position": "WR",
#   "AverageDraftPosition": 22.9,
#   "AverageDraftPositionPPR": 18.0,
#   "ByeWeek": 12,
#   "LastSeasonFantasyPoints": 194.9,
#   "ProjectedFantasyPoints": 203.3,
#   "AuctionValue": 38,
#   "AuctionValuePPR": 42,
#   "AverageDraftPositionIDP": 8,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21769",
#   "PlayerID": 21769,
#   "Name": "Clyde Edwards-Helaire",
#   "Team": "KC",
#   "Position": "RB",
#   "AverageDraftPosition": 23.9,
#   "AverageDraftPositionPPR": 21.7,
#   "ByeWeek": 12,
#   "LastSeasonFantasyPoints": 157.9,
#   "ProjectedFantasyPoints": 212.5,
#   "AuctionValue": 39,
#   "AuctionValuePPR": 39,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19802",
#   "PlayerID": 19802,
#   "Name": "Calvin Ridley",
#   "Team": "ATL",
#   "Position": "WR",
#   "AverageDraftPosition": 24.0,
#   "AverageDraftPositionPPR": 22.0,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 216.0,
#   "ProjectedFantasyPoints": 205.4,
#   "AuctionValue": 42,
#   "AuctionValuePPR": 41,
#   "AverageDraftPositionIDP": 62,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21674",
#   "PlayerID": 21674,
#   "Name": "J.K. Dobbins",
#   "Team": "BAL",
#   "Position": "RB",
#   "AverageDraftPosition": 25.8,
#   "AverageDraftPositionPPR": 27.9,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 169.8,
#   "ProjectedFantasyPoints": 215.4,
#   "AuctionValue": 39,
#   "AuctionValuePPR": 35,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20824",
#   "PlayerID": 20824,
#   "Name": "Josh Jacobs",
#   "Team": "LV",
#   "Position": "RB",
#   "AverageDraftPosition": 27.5,
#   "AverageDraftPositionPPR": 39.3,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 223.7,
#   "ProjectedFantasyPoints": 212.2,
#   "AuctionValue": 32,
#   "AuctionValuePPR": 30,
#   "AverageDraftPositionIDP": 43,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21685",
#   "PlayerID": 21685,
#   "Name": "Justin Jefferson",
#   "Team": "MIN",
#   "Position": "WR",
#   "AverageDraftPosition": 27.6,
#   "AverageDraftPositionPPR": 27.0,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 210.0,
#   "ProjectedFantasyPoints": 205.5,
#   "AuctionValue": 37,
#   "AuctionValuePPR": 37,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21042",
#   "PlayerID": 21042,
#   "Name": "A.J. Brown",
#   "Team": "TEN",
#   "Position": "WR",
#   "AverageDraftPosition": 28.9,
#   "AverageDraftPositionPPR": 30.1,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 193.5,
#   "ProjectedFantasyPoints": 213.0,
#   "AuctionValue": 41,
#   "AuctionValuePPR": 39,
#   "AverageDraftPositionIDP": 203,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16964",
#   "PlayerID": 16964,
#   "Name": "Darren Waller",
#   "Team": "LV",
#   "Position": "TE",
#   "AverageDraftPosition": 31.4,
#   "AverageDraftPositionPPR": 25.3,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 193.6,
#   "ProjectedFantasyPoints": 172.3,
#   "AuctionValue": 28,
#   "AuctionValuePPR": 34,
#   "AverageDraftPositionIDP": 184,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19119",
#   "PlayerID": 19119,
#   "Name": "Chris Carson",
#   "Team": "SEA",
#   "Position": "RB",
#   "AverageDraftPosition": 32.8,
#   "AverageDraftPositionPPR": 33.5,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 170.1,
#   "ProjectedFantasyPoints": 206.7,
#   "AuctionValue": 33,
#   "AuctionValuePPR": 29,
#   "AverageDraftPositionIDP": 53,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "17960",
#   "PlayerID": 17960,
#   "Name": "Michael Thomas",
#   "Team": "NO",
#   "Position": "WR",
#   "AverageDraftPosition": 33.7,
#   "AverageDraftPositionPPR": 32.4,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 49.5,
#   "ProjectedFantasyPoints": 184.5,
#   "AuctionValue": 26,
#   "AuctionValuePPR": 28,
#   "AverageDraftPositionIDP": 14,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20882",
#   "PlayerID": 20882,
#   "Name": "David Montgomery",
#   "Team": "CHI",
#   "Position": "RB",
#   "AverageDraftPosition": 33.8,
#   "AverageDraftPositionPPR": 35.2,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 237.8,
#   "ProjectedFantasyPoints": 214.6,
#   "AuctionValue": 34,
#   "AuctionValuePPR": 32,
#   "AverageDraftPositionIDP": 54,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19063",
#   "PlayerID": 19063,
#   "Name": "George Kittle",
#   "Team": "SF",
#   "Position": "TE",
#   "AverageDraftPosition": 34.6,
#   "AverageDraftPositionPPR": 32.8,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 87.0,
#   "ProjectedFantasyPoints": 169.8,
#   "AuctionValue": 41,
#   "AuctionValuePPR": 38,
#   "AverageDraftPositionIDP": 43,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19801",
#   "PlayerID": 19801,
#   "Name": "Josh Allen",
#   "Team": "BUF",
#   "Position": "QB",
#   "AverageDraftPosition": 36.2,
#   "AverageDraftPositionPPR": 42.3,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 445.6,
#   "ProjectedFantasyPoints": 432.8,
#   "AuctionValue": 29,
#   "AuctionValuePPR": 29,
#   "AverageDraftPositionIDP": 166,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "15076",
#   "PlayerID": 15076,
#   "Name": "Keenan Allen",
#   "Team": "LAC",
#   "Position": "WR",
#   "AverageDraftPosition": 36.3,
#   "AverageDraftPositionPPR": 31.5,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 163.7,
#   "ProjectedFantasyPoints": 168.4,
#   "AuctionValue": 25,
#   "AuctionValuePPR": 26,
#   "AverageDraftPositionIDP": 37,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20933",
#   "PlayerID": 20933,
#   "Name": "Miles Sanders",
#   "Team": "PHI",
#   "Position": "RB",
#   "AverageDraftPosition": 36.8,
#   "AverageDraftPositionPPR": 36.4,
#   "ByeWeek": 14,
#   "LastSeasonFantasyPoints": 160.6,
#   "ProjectedFantasyPoints": 210.4,
#   "AuctionValue": 36,
#   "AuctionValuePPR": 33,
#   "AverageDraftPositionIDP": 105,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20873",
#   "PlayerID": 20873,
#   "Name": "Terry McLaurin",
#   "Team": "WAS",
#   "Position": "WR",
#   "AverageDraftPosition": 39.0,
#   "AverageDraftPositionPPR": 37.8,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 154.3,
#   "ProjectedFantasyPoints": 183.0,
#   "AuctionValue": 35,
#   "AuctionValuePPR": 35,
#   "AverageDraftPositionIDP": 244,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21684",
#   "PlayerID": 21684,
#   "Name": "D'Andre Swift",
#   "Team": "DET",
#   "Position": "RB",
#   "AverageDraftPosition": 39.3,
#   "AverageDraftPositionPPR": 36.4,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 162.2,
#   "ProjectedFantasyPoints": 208.9,
#   "AuctionValue": 38,
#   "AuctionValuePPR": 41,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16597",
#   "PlayerID": 16597,
#   "Name": "Mike Evans",
#   "Team": "TB",
#   "Position": "WR",
#   "AverageDraftPosition": 42.2,
#   "AverageDraftPositionPPR": 48.3,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 201.5,
#   "ProjectedFantasyPoints": 184.6,
#   "AuctionValue": 32,
#   "AuctionValuePPR": 26,
#   "AverageDraftPositionIDP": 27,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20889",
#   "PlayerID": 20889,
#   "Name": "Kyler Murray",
#   "Team": "ARI",
#   "Position": "QB",
#   "AverageDraftPosition": 43.0,
#   "AverageDraftPositionPPR": 50.0,
#   "ByeWeek": 12,
#   "LastSeasonFantasyPoints": 427.2,
#   "ProjectedFantasyPoints": 407.2,
#   "AuctionValue": 24,
#   "AuctionValuePPR": 25,
#   "AverageDraftPositionIDP": 136,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21970",
#   "PlayerID": 21970,
#   "Name": "James Robinson",
#   "Team": "JAX",
#   "Position": "RB",
#   "AverageDraftPosition": 43.8,
#   "AverageDraftPositionPPR": 53.0,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 227.2,
#   "ProjectedFantasyPoints": 159.6,
#   "AuctionValue": 11,
#   "AuctionValuePPR": 10,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "13291",
#   "PlayerID": 13291,
#   "Name": "Julio Jones",
#   "Team": "TEN",
#   "Position": "WR",
#   "AverageDraftPosition": 43.9,
#   "AverageDraftPositionPPR": 45.3,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 107.3,
#   "ProjectedFantasyPoints": 172.7,
#   "AuctionValue": 21,
#   "AuctionValuePPR": 19,
#   "AverageDraftPositionIDP": 14,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16263",
#   "PlayerID": 16263,
#   "Name": "Allen Robinson II",
#   "Team": "CHI",
#   "Position": "WR",
#   "AverageDraftPosition": 45.3,
#   "AverageDraftPositionPPR": 40.9,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 181.5,
#   "ProjectedFantasyPoints": 183.4,
#   "AuctionValue": 28,
#   "AuctionValuePPR": 28,
#   "AverageDraftPositionIDP": 85,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18944",
#   "PlayerID": 18944,
#   "Name": "Kareem Hunt",
#   "Team": "CLE",
#   "Position": "RB",
#   "AverageDraftPosition": 47.6,
#   "AverageDraftPositionPPR": 53.4,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 203.6,
#   "ProjectedFantasyPoints": 163.7,
#   "AuctionValue": 16,
#   "AuctionValuePPR": 14,
#   "AverageDraftPositionIDP": 124,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18055",
#   "PlayerID": 18055,
#   "Name": "Dak Prescott",
#   "Team": "DAL",
#   "Position": "QB",
#   "AverageDraftPosition": 48.5,
#   "AverageDraftPositionPPR": 60.2,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 151.9,
#   "ProjectedFantasyPoints": 402.5,
#   "AuctionValue": 20,
#   "AuctionValuePPR": 21,
#   "AverageDraftPositionIDP": 126,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "15534",
#   "PlayerID": 15534,
#   "Name": "Adam Thielen",
#   "Team": "MIN",
#   "Position": "WR",
#   "AverageDraftPosition": 48.8,
#   "AverageDraftPositionPPR": 59.6,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 203.0,
#   "ProjectedFantasyPoints": 154.5,
#   "AuctionValue": 24,
#   "AuctionValuePPR": 21,
#   "AverageDraftPositionIDP": 33,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20768",
#   "PlayerID": 20768,
#   "Name": "Myles Gaskin",
#   "Team": "MIA",
#   "Position": "RB",
#   "AverageDraftPosition": 49.9,
#   "AverageDraftPositionPPR": 44.7,
#   "ByeWeek": 14,
#   "LastSeasonFantasyPoints": 139.0,
#   "ProjectedFantasyPoints": 188.2,
#   "AuctionValue": 24,
#   "AuctionValuePPR": 23,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19781",
#   "PlayerID": 19781,
#   "Name": "Lamar Jackson",
#   "Team": "BAL",
#   "Position": "QB",
#   "AverageDraftPosition": 51.0,
#   "AverageDraftPositionPPR": 56.2,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 375.4,
#   "ProjectedFantasyPoints": 398.3,
#   "AuctionValue": 19,
#   "AuctionValuePPR": 17,
#   "AverageDraftPositionIDP": 138,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21679",
#   "PlayerID": 21679,
#   "Name": "CeeDee Lamb",
#   "Team": "DAL",
#   "Position": "WR",
#   "AverageDraftPosition": 51.7,
#   "AverageDraftPositionPPR": 40.9,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 155.3,
#   "ProjectedFantasyPoints": 167.0,
#   "AuctionValue": 21,
#   "AuctionValuePPR": 21,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16765",
#   "PlayerID": 16765,
#   "Name": "Amari Cooper",
#   "Team": "DAL",
#   "Position": "WR",
#   "AverageDraftPosition": 52.7,
#   "AverageDraftPositionPPR": 49.5,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 163.3,
#   "ProjectedFantasyPoints": 161.1,
#   "AuctionValue": 26,
#   "AuctionValuePPR": 26,
#   "AverageDraftPositionIDP": 39,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "17217",
#   "PlayerID": 17217,
#   "Name": "Raheem Mostert",
#   "Team": "SF",
#   "Position": "RB",
#   "AverageDraftPosition": 54.0,
#   "AverageDraftPositionPPR": 61.8,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 94.4,
#   "ProjectedFantasyPoints": 161.9,
#   "AuctionValue": 12,
#   "AuctionValuePPR": 10,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22508",
#   "PlayerID": 22508,
#   "Name": "Kyle Pitts",
#   "Team": "ATL",
#   "Position": "TE",
#   "AverageDraftPosition": 55.0,
#   "AverageDraftPositionPPR": 46.0,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 135.8,
#   "AuctionValue": 12,
#   "AuctionValuePPR": 15,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18880",
#   "PlayerID": 18880,
#   "Name": "Chris Godwin",
#   "Team": "TB",
#   "Position": "WR",
#   "AverageDraftPosition": 57.6,
#   "AverageDraftPositionPPR": 55.3,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 142.1,
#   "ProjectedFantasyPoints": 170.7,
#   "AuctionValue": 20,
#   "AuctionValuePPR": 19,
#   "AverageDraftPositionIDP": 62,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16887",
#   "PlayerID": 16887,
#   "Name": "Mike Davis",
#   "Team": "ATL",
#   "Position": "RB",
#   "AverageDraftPosition": 59.0,
#   "AverageDraftPositionPPR": 48.3,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 166.4,
#   "ProjectedFantasyPoints": 179.7,
#   "AuctionValue": 17,
#   "AuctionValuePPR": 14,
#   "AverageDraftPositionIDP": 229,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "14871",
#   "PlayerID": 14871,
#   "Name": "Robert Woods",
#   "Team": "LAR",
#   "Position": "WR",
#   "AverageDraftPosition": 59.4,
#   "AverageDraftPositionPPR": 50.4,
#   "ByeWeek": 11,
#   "LastSeasonFantasyPoints": 175.0,
#   "ProjectedFantasyPoints": 164.8,
#   "AuctionValue": 18,
#   "AuctionValuePPR": 19,
#   "AverageDraftPositionIDP": 52,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19803",
#   "PlayerID": 19803,
#   "Name": "Mark Andrews",
#   "Team": "BAL",
#   "Position": "TE",
#   "AverageDraftPosition": 59.7,
#   "AverageDraftPositionPPR": 59.2,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 126.4,
#   "ProjectedFantasyPoints": 148.2,
#   "AuctionValue": 21,
#   "AuctionValuePPR": 23,
#   "AverageDraftPositionIDP": 166,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16776",
#   "PlayerID": 16776,
#   "Name": "Melvin Gordon III",
#   "Team": "DEN",
#   "Position": "RB",
#   "AverageDraftPosition": 61.7,
#   "AverageDraftPositionPPR": 78.3,
#   "ByeWeek": 11,
#   "LastSeasonFantasyPoints": 187.7,
#   "ProjectedFantasyPoints": 139.7,
#   "AuctionValue": 11,
#   "AuctionValuePPR": 5,
#   "AverageDraftPositionIDP": 41,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21681",
#   "PlayerID": 21681,
#   "Name": "Justin Herbert",
#   "Team": "LAC",
#   "Position": "QB",
#   "AverageDraftPosition": 61.9,
#   "AverageDraftPositionPPR": 66.2,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 375.4,
#   "ProjectedFantasyPoints": 385.7,
#   "AuctionValue": 16,
#   "AuctionValuePPR": 17,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "14536",
#   "PlayerID": 14536,
#   "Name": "Russell Wilson",
#   "Team": "SEA",
#   "Position": "QB",
#   "AverageDraftPosition": 64.3,
#   "AverageDraftPositionPPR": 73.7,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 405.8,
#   "ProjectedFantasyPoints": 383.5,
#   "AuctionValue": 15,
#   "AuctionValuePPR": 15,
#   "AverageDraftPositionIDP": 88,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22564",
#   "PlayerID": 22564,
#   "Name": "Ja'Marr Chase",
#   "Team": "CIN",
#   "Position": "WR",
#   "AverageDraftPosition": 65.6,
#   "AverageDraftPositionPPR": 72.8,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 151.4,
#   "AuctionValue": 12,
#   "AuctionValuePPR": 14,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20805",
#   "PlayerID": 20805,
#   "Name": "T.J. Hockenson",
#   "Team": "DET",
#   "Position": "TE",
#   "AverageDraftPosition": 67.2,
#   "AverageDraftPositionPPR": 64.0,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 122.2,
#   "ProjectedFantasyPoints": 130.4,
#   "AuctionValue": 23,
#   "AuctionValuePPR": 15,
#   "AverageDraftPositionIDP": 148,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18977",
#   "PlayerID": 18977,
#   "Name": "Kenny Golladay",
#   "Team": "NYG",
#   "Position": "WR",
#   "AverageDraftPosition": 67.3,
#   "AverageDraftPositionPPR": 69.6,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 51.7,
#   "ProjectedFantasyPoints": 163.4,
#   "AuctionValue": 19,
#   "AuctionValuePPR": 16,
#   "AverageDraftPositionIDP": 62,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18882",
#   "PlayerID": 18882,
#   "Name": "Cooper Kupp",
#   "Team": "LAR",
#   "Position": "WR",
#   "AverageDraftPosition": 68.1,
#   "AverageDraftPositionPPR": 57.6,
#   "ByeWeek": 11,
#   "LastSeasonFantasyPoints": 131.6,
#   "ProjectedFantasyPoints": 154.2,
#   "AuctionValue": 17,
#   "AuctionValuePPR": 18,
#   "AverageDraftPositionIDP": 68,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19919",
#   "PlayerID": 19919,
#   "Name": "Chase Edmonds",
#   "Team": "ARI",
#   "Position": "RB",
#   "AverageDraftPosition": 68.6,
#   "AverageDraftPositionPPR": 68.2,
#   "ByeWeek": 12,
#   "LastSeasonFantasyPoints": 129.7,
#   "ProjectedFantasyPoints": 162.3,
#   "AuctionValue": 16,
#   "AuctionValuePPR": 14,
#   "AverageDraftPositionIDP": 215,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21696",
#   "PlayerID": 21696,
#   "Name": "Travis Etienne Jr.",
#   "Team": "JAX",
#   "Position": "RB",
#   "AverageDraftPosition": 69.4,
#   "AverageDraftPositionPPR": 63.3,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 153.7,
#   "AuctionValue": 16,
#   "AuctionValuePPR": 16,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16830",
#   "PlayerID": 16830,
#   "Name": "Tyler Lockett",
#   "Team": "SEA",
#   "Position": "WR",
#   "AverageDraftPosition": 69.6,
#   "AverageDraftPositionPPR": 70.2,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 186.6,
#   "ProjectedFantasyPoints": 151.3,
#   "AuctionValue": 17,
#   "AuctionValuePPR": 16,
#   "AverageDraftPositionIDP": 55,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21077",
#   "PlayerID": 21077,
#   "Name": "Diontae Johnson",
#   "Team": "PIT",
#   "Position": "WR",
#   "AverageDraftPosition": 71.9,
#   "AverageDraftPositionPPR": 61.9,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 150.9,
#   "ProjectedFantasyPoints": 150.3,
#   "AuctionValue": 17,
#   "AuctionValuePPR": 20,
#   "AverageDraftPositionIDP": 252,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "2593",
#   "PlayerID": 2593,
#   "Name": "Aaron Rodgers",
#   "Team": "GB",
#   "Position": "QB",
#   "AverageDraftPosition": 73.7,
#   "AverageDraftPositionPPR": 81.6,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 431.2,
#   "ProjectedFantasyPoints": 372.1,
#   "AuctionValue": 14,
#   "AuctionValuePPR": 14,
#   "AverageDraftPositionIDP": 54,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16389",
#   "PlayerID": 16389,
#   "Name": "Odell Beckham Jr.",
#   "Team": "CLE",
#   "Position": "WR",
#   "AverageDraftPosition": 75.2,
#   "AverageDraftPositionPPR": 77.9,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 72.0,
#   "ProjectedFantasyPoints": 145.0,
#   "AuctionValue": 14,
#   "AuctionValuePPR": 11,
#   "AverageDraftPositionIDP": 15,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22558",
#   "PlayerID": 22558,
#   "Name": "Javonte Williams",
#   "Team": "DEN",
#   "Position": "RB",
#   "AverageDraftPosition": 75.9,
#   "AverageDraftPositionPPR": 70.8,
#   "ByeWeek": 11,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 157.3,
#   "AuctionValue": 11,
#   "AuctionValuePPR": 10,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19844",
#   "PlayerID": 19844,
#   "Name": "DJ Moore",
#   "Team": "CAR",
#   "Position": "WR",
#   "AverageDraftPosition": 76.3,
#   "AverageDraftPositionPPR": 66.2,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 164.1,
#   "ProjectedFantasyPoints": 168.5,
#   "AuctionValue": 21,
#   "AuctionValuePPR": 21,
#   "AverageDraftPositionIDP": 78,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20790",
#   "PlayerID": 20790,
#   "Name": "Damien Harris",
#   "Team": "NE",
#   "Position": "RB",
#   "AverageDraftPosition": 78.2,
#   "AverageDraftPositionPPR": 73.5,
#   "ByeWeek": 14,
#   "LastSeasonFantasyPoints": 97.3,
#   "ProjectedFantasyPoints": 155.4,
#   "AuctionValue": 14,
#   "AuctionValuePPR": 8,
#   "AverageDraftPositionIDP": 180,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21747",
#   "PlayerID": 21747,
#   "Name": "Brandon Aiyuk",
#   "Team": "SF",
#   "Position": "WR",
#   "AverageDraftPosition": 78.3,
#   "AverageDraftPositionPPR": 75.4,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 140.4,
#   "ProjectedFantasyPoints": 148.7,
#   "AuctionValue": 17,
#   "AuctionValuePPR": 16,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19861",
#   "PlayerID": 19861,
#   "Name": "Ronald Jones II",
#   "Team": "TB",
#   "Position": "RB",
#   "AverageDraftPosition": 78.8,
#   "AverageDraftPositionPPR": 88.7,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 178.6,
#   "ProjectedFantasyPoints": 148.8,
#   "AuctionValue": 10,
#   "AuctionValuePPR": 8,
#   "AverageDraftPositionIDP": 165,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21752",
#   "PlayerID": 21752,
#   "Name": "Chase Claypool",
#   "Team": "PIT",
#   "Position": "WR",
#   "AverageDraftPosition": 82.8,
#   "AverageDraftPositionPPR": 82.6,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 172.5,
#   "ProjectedFantasyPoints": 149.6,
#   "AuctionValue": 16,
#   "AuctionValuePPR": 16,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "4314",
#   "PlayerID": 4314,
#   "Name": "Tom Brady",
#   "Team": "TB",
#   "Position": "QB",
#   "AverageDraftPosition": 83.2,
#   "AverageDraftPositionPPR": 92.2,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 381.2,
#   "ProjectedFantasyPoints": 364.2,
#   "AuctionValue": 10,
#   "AuctionValuePPR": 10,
#   "AverageDraftPositionIDP": 123,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18803",
#   "PlayerID": 18803,
#   "Name": "Leonard Fournette",
#   "Team": "TB",
#   "Position": "RB",
#   "AverageDraftPosition": 83.8,
#   "AverageDraftPositionPPR": 85.5,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 108.3,
#   "ProjectedFantasyPoints": 142.0,
#   "AuctionValue": 12,
#   "AuctionValuePPR": 8,
#   "AverageDraftPositionIDP": 28,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21690",
#   "PlayerID": 21690,
#   "Name": "Tee Higgins",
#   "Team": "CIN",
#   "Position": "WR",
#   "AverageDraftPosition": 84.9,
#   "AverageDraftPositionPPR": 80.1,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 143.9,
#   "ProjectedFantasyPoints": 146.5,
#   "AuctionValue": 15,
#   "AuctionValuePPR": 15,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "10974",
#   "PlayerID": 10974,
#   "Name": "Rob Gronkowski",
#   "Team": "TB",
#   "Position": "TE",
#   "AverageDraftPosition": 86.3,
#   "AverageDraftPositionPPR": 130.6,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 117.7,
#   "ProjectedFantasyPoints": 109.1,
#   "AuctionValue": 3,
#   "AuctionValuePPR": 9,
#   "AverageDraftPositionIDP": 266,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18983",
#   "PlayerID": 18983,
#   "Name": "James Conner",
#   "Team": "ARI",
#   "Position": "RB",
#   "AverageDraftPosition": 87.8,
#   "AverageDraftPositionPPR": 97.6,
#   "ByeWeek": 12,
#   "LastSeasonFantasyPoints": 146.2,
#   "ProjectedFantasyPoints": 135.7,
#   "AuctionValue": 8,
#   "AuctionValuePPR": 5,
#   "AverageDraftPositionIDP": 10,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19816",
#   "PlayerID": 19816,
#   "Name": "DJ Chark Jr.",
#   "Team": "JAX",
#   "Position": "WR",
#   "AverageDraftPosition": 89.7,
#   "AverageDraftPositionPPR": 91.9,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 113.5,
#   "ProjectedFantasyPoints": 149.8,
#   "AuctionValue": 14,
#   "AuctionValuePPR": 11,
#   "AverageDraftPositionIDP": 258,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21687",
#   "PlayerID": 21687,
#   "Name": "DeVonta Smith",
#   "Team": "PHI",
#   "Position": "WR",
#   "AverageDraftPosition": 89.7,
#   "AverageDraftPositionPPR": 88.7,
#   "ByeWeek": 14,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 138.0,
#   "AuctionValue": 8,
#   "AuctionValuePPR": 8,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21831",
#   "PlayerID": 21831,
#   "Name": "Jalen Hurts",
#   "Team": "PHI",
#   "Position": "QB",
#   "AverageDraftPosition": 90.7,
#   "AverageDraftPositionPPR": 107.3,
#   "ByeWeek": 14,
#   "LastSeasonFantasyPoints": 122.3,
#   "ProjectedFantasyPoints": 364.4,
#   "AuctionValue": 10,
#   "AuctionValuePPR": 10,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16847",
#   "PlayerID": 16847,
#   "Name": "David Johnson",
#   "Team": "HOU",
#   "Position": "RB",
#   "AverageDraftPosition": 91.4,
#   "AverageDraftPositionPPR": 93.4,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 165.3,
#   "ProjectedFantasyPoints": 146.7,
#   "AuctionValue": 10,
#   "AuctionValuePPR": 9,
#   "AverageDraftPositionIDP": 11,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19800",
#   "PlayerID": 19800,
#   "Name": "Courtland Sutton",
#   "Team": "DEN",
#   "Position": "WR",
#   "AverageDraftPosition": 92.9,
#   "AverageDraftPositionPPR": 91.5,
#   "ByeWeek": 11,
#   "LastSeasonFantasyPoints": 8.4,
#   "ProjectedFantasyPoints": 147.6,
#   "AuctionValue": 14,
#   "AuctionValuePPR": 12,
#   "AverageDraftPositionIDP": 113,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "9038",
#   "PlayerID": 9038,
#   "Name": "Matthew Stafford",
#   "Team": "LAR",
#   "Position": "QB",
#   "AverageDraftPosition": 93.4,
#   "AverageDraftPositionPPR": 93.7,
#   "ByeWeek": 11,
#   "LastSeasonFantasyPoints": 293.9,
#   "ProjectedFantasyPoints": 350.3,
#   "AuctionValue": 6,
#   "AuctionValuePPR": 5,
#   "AverageDraftPositionIDP": 178,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21802",
#   "PlayerID": 21802,
#   "Name": "A.J. Dillon",
#   "Team": "GB",
#   "Position": "RB",
#   "AverageDraftPosition": 93.5,
#   "AverageDraftPositionPPR": 103.6,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 43.2,
#   "ProjectedFantasyPoints": 125.8,
#   "AuctionValue": 6,
#   "AuctionValuePPR": 4,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "17975",
#   "PlayerID": 17975,
#   "Name": "Hunter Henry",
#   "Team": "NE",
#   "Position": "TE",
#   "AverageDraftPosition": 94.9,
#   "AverageDraftPositionPPR": 107.5,
#   "ByeWeek": 14,
#   "LastSeasonFantasyPoints": 96.2,
#   "ProjectedFantasyPoints": 102.4,
#   "AuctionValue": 4,
#   "AuctionValuePPR": 5,
#   "AverageDraftPositionIDP": 82,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21784",
#   "PlayerID": 21784,
#   "Name": "Zack Moss",
#   "Team": "BUF",
#   "Position": "RB",
#   "AverageDraftPosition": 95.4,
#   "AverageDraftPositionPPR": 97.7,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 98.8,
#   "ProjectedFantasyPoints": 131.9,
#   "AuctionValue": 9,
#   "AuctionValuePPR": 6,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18883",
#   "PlayerID": 18883,
#   "Name": "JuJu Smith-Schuster",
#   "Team": "PIT",
#   "Position": "WR",
#   "AverageDraftPosition": 95.8,
#   "AverageDraftPositionPPR": 96.2,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 154.6,
#   "ProjectedFantasyPoints": 145.1,
#   "AuctionValue": 9,
#   "AuctionValuePPR": 10,
#   "AverageDraftPositionIDP": 18,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20941",
#   "PlayerID": 20941,
#   "Name": "Devin Singletary",
#   "Team": "BUF",
#   "Position": "RB",
#   "AverageDraftPosition": 98.9,
#   "AverageDraftPositionPPR": 114.4,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 119.1,
#   "ProjectedFantasyPoints": 110.5,
#   "AuctionValue": 6,
#   "AuctionValuePPR": 4,
#   "AverageDraftPositionIDP": 125,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16656",
#   "PlayerID": 16656,
#   "Name": "Logan Thomas",
#   "Team": "WAS",
#   "Position": "TE",
#   "AverageDraftPosition": 99.8,
#   "AverageDraftPositionPPR": 84.9,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 118.0,
#   "ProjectedFantasyPoints": 104.8,
#   "AuctionValue": 9,
#   "AuctionValuePPR": 6,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "17986",
#   "PlayerID": 17986,
#   "Name": "Tyler Boyd",
#   "Team": "CIN",
#   "Position": "WR",
#   "AverageDraftPosition": 102.5,
#   "AverageDraftPositionPPR": 110.2,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 128.2,
#   "ProjectedFantasyPoints": 129.1,
#   "AuctionValue": 6,
#   "AuctionValuePPR": 9,
#   "AverageDraftPositionIDP": 69,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21693",
#   "PlayerID": 21693,
#   "Name": "Joe Burrow",
#   "Team": "CIN",
#   "Position": "QB",
#   "AverageDraftPosition": 103.1,
#   "AverageDraftPositionPPR": 112.3,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 196.0,
#   "ProjectedFantasyPoints": 338.7,
#   "AuctionValue": 5,
#   "AuctionValuePPR": 5,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18003",
#   "PlayerID": 18003,
#   "Name": "Kenyan Drake",
#   "Team": "LV",
#   "Position": "RB",
#   "AverageDraftPosition": 103.9,
#   "AverageDraftPositionPPR": 103.3,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 188.6,
#   "ProjectedFantasyPoints": 124.1,
#   "AuctionValue": 8,
#   "AuctionValuePPR": 6,
#   "AverageDraftPositionIDP": 107,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "18187",
#   "PlayerID": 18187,
#   "Name": "Robby Anderson",
#   "Team": "CAR",
#   "Position": "WR",
#   "AverageDraftPosition": 104.8,
#   "AverageDraftPositionPPR": 101.1,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 145.6,
#   "ProjectedFantasyPoints": 139.5,
#   "AuctionValue": 10,
#   "AuctionValuePPR": 11,
#   "AverageDraftPositionIDP": 88,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21801",
#   "PlayerID": 21801,
#   "Name": "Trey Sermon",
#   "Team": "SF",
#   "Position": "RB",
#   "AverageDraftPosition": 104.9,
#   "AverageDraftPositionPPR": 89.1,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 126.0,
#   "AuctionValue": 6,
#   "AuctionValuePPR": 5,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "19863",
#   "PlayerID": 19863,
#   "Name": "Dallas Goedert",
#   "Team": "PHI",
#   "Position": "TE",
#   "AverageDraftPosition": 105.1,
#   "AverageDraftPositionPPR": 85.6,
#   "ByeWeek": 14,
#   "LastSeasonFantasyPoints": 79.4,
#   "ProjectedFantasyPoints": 124.7,
#   "AuctionValue": 17,
#   "AuctionValuePPR": 12,
#   "AverageDraftPositionIDP": 180,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20239",
#   "PlayerID": 20239,
#   "Name": "Gus Edwards",
#   "Team": "BAL",
#   "Position": "RB",
#   "AverageDraftPosition": 105.4,
#   "AverageDraftPositionPPR": 113.7,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 134.5,
#   "ProjectedFantasyPoints": 126.0,
#   "AuctionValue": 6,
#   "AuctionValuePPR": 4,
#   "AverageDraftPositionIDP": 230,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21045",
#   "PlayerID": 21045,
#   "Name": "Marquise Brown",
#   "Team": "BAL",
#   "Position": "WR",
#   "AverageDraftPosition": 108.4,
#   "AverageDraftPositionPPR": 133.8,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 141.0,
#   "ProjectedFantasyPoints": 118.2,
#   "AuctionValue": 5,
#   "AuctionValuePPR": 5,
#   "AverageDraftPositionIDP": 196,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "13799",
#   "PlayerID": 13799,
#   "Name": "Ryan Tannehill",
#   "Team": "TEN",
#   "Position": "QB",
#   "AverageDraftPosition": 108.6,
#   "AverageDraftPositionPPR": 113.5,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 387.3,
#   "ProjectedFantasyPoints": 360.8,
#   "AuctionValue": 9,
#   "AuctionValuePPR": 8,
#   "AverageDraftPositionIDP": 284,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "16020",
#   "PlayerID": 16020,
#   "Name": "Jarvis Landry",
#   "Team": "CLE",
#   "Position": "WR",
#   "AverageDraftPosition": 108.6,
#   "AverageDraftPositionPPR": 125.0,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 130.8,
#   "ProjectedFantasyPoints": 123.9,
#   "AuctionValue": 4,
#   "AuctionValuePPR": 4,
#   "AverageDraftPositionIDP": 76,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20932",
#   "PlayerID": 20932,
#   "Name": "Deebo Samuel",
#   "Team": "SF",
#   "Position": "WR",
#   "AverageDraftPosition": 110.5,
#   "AverageDraftPositionPPR": 99.2,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 53.8,
#   "ProjectedFantasyPoints": 141.2,
#   "AuctionValue": 10,
#   "AuctionValuePPR": 10,
#   "AverageDraftPositionIDP": 192,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22553",
#   "PlayerID": 22553,
#   "Name": "Michael Carter",
#   "Team": "NYJ",
#   "Position": "RB",
#   "AverageDraftPosition": 112.5,
#   "AverageDraftPositionPPR": 83.1,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 0.0,
# ...
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21809",
#   "PlayerID": 21809,
#   "Name": "Steven Montez",
#   "Team": "WAS",
#   "Position": "QB",
#   "AverageDraftPosition": 1778.9,
#   "AverageDraftPositionPPR": 1766.4,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21812",
#   "PlayerID": 21812,
#   "Name": "Nate Stanley",
#   "Team": "MIN",
#   "Position": "QB",
#   "AverageDraftPosition": 1780.0,
#   "AverageDraftPositionPPR": 1767.6,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21814",
#   "PlayerID": 21814,
#   "Name": "Jake Luton",
#   "Team": "JAX",
#   "Position": "QB",
#   "AverageDraftPosition": 1781.1,
#   "AverageDraftPositionPPR": 1768.7,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 31.9,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21816",
#   "PlayerID": 21816,
#   "Name": "Anthony Gordon",
#   "Team": "KC",
#   "Position": "QB",
#   "AverageDraftPosition": 1782.2,
#   "AverageDraftPositionPPR": 1769.8,
#   "ByeWeek": 12,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21819",
#   "PlayerID": 21819,
#   "Name": "Bryce Perkins",
#   "Team": "LAR",
#   "Position": "QB",
#   "AverageDraftPosition": 1783.4,
#   "AverageDraftPositionPPR": 1771.0,
#   "ByeWeek": 11,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21822",
#   "PlayerID": 21822,
#   "Name": "Cole McDonald",
#   "Team": null,
#   "Position": "QB",
#   "AverageDraftPosition": 1784.5,
#   "AverageDraftPositionPPR": 1772.1,
#   "ByeWeek": null,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21825",
#   "PlayerID": 21825,
#   "Name": "Spencer Brown",
#   "Team": "CAR",
#   "Position": "RB",
#   "AverageDraftPosition": 1785.6,
#   "AverageDraftPositionPPR": 1773.2,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21826",
#   "PlayerID": 21826,
#   "Name": "Darius Bradwell",
#   "Team": "LAC",
#   "Position": "RB",
#   "AverageDraftPosition": 1786.8,
#   "AverageDraftPositionPPR": 1774.3,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21849",
#   "PlayerID": 21849,
#   "Name": "Caleb Huntley",
#   "Team": "ATL",
#   "Position": "RB",
#   "AverageDraftPosition": 1787.9,
#   "AverageDraftPositionPPR": 1775.5,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21850",
#   "PlayerID": 21850,
#   "Name": "Tavien Feaster",
#   "Team": "ARI",
#   "Position": "RB",
#   "AverageDraftPosition": 1789.0,
#   "AverageDraftPositionPPR": 1776.6,
#   "ByeWeek": 12,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21865",
#   "PlayerID": 21865,
#   "Name": "Stephen Sullivan",
#   "Team": "CAR",
#   "Position": "TE",
#   "AverageDraftPosition": 1790.1,
#   "AverageDraftPositionPPR": 1777.7,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21971",
#   "PlayerID": 21971,
#   "Name": "Sewo Olonilua",
#   "Team": "DAL",
#   "Position": "RB",
#   "AverageDraftPosition": 1863.5,
#   "AverageDraftPositionPPR": 1851.0,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22113",
#   "PlayerID": 22113,
#   "Name": "Eli Wolf",
#   "Team": "BAL",
#   "Position": "TE",
#   "AverageDraftPosition": 1941.3,
#   "AverageDraftPositionPPR": 1928.9,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22123",
#   "PlayerID": 22123,
#   "Name": "Austin MacGinnis",
#   "Team": "LAR",
#   "Position": "K",
#   "AverageDraftPosition": 1942.4,
#   "AverageDraftPositionPPR": 1930.0,
#   "ByeWeek": 11,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22146",
#   "PlayerID": 22146,
#   "Name": "Ben DiNucci",
#   "Team": "DAL",
#   "Position": "QB",
#   "AverageDraftPosition": 1949.2,
#   "AverageDraftPositionPPR": 1936.8,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 8.9,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22151",
#   "PlayerID": 22151,
#   "Name": "Tommy Stevens",
#   "Team": null,
#   "Position": "QB",
#   "AverageDraftPosition": 1954.8,
#   "AverageDraftPositionPPR": 1942.4,
#   "ByeWeek": null,
#   "LastSeasonFantasyPoints": 3.1,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22511",
#   "PlayerID": 22511,
#   "Name": "Quintin Morris",
#   "Team": "BUF",
#   "Position": "TE",
#   "AverageDraftPosition": 2034.9,
#   "AverageDraftPositionPPR": 2022.5,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22518",
#   "PlayerID": 22518,
#   "Name": "Matt Bushman",
#   "Team": "LV",
#   "Position": "TE",
#   "AverageDraftPosition": 2036.0,
#   "AverageDraftPositionPPR": 2023.6,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22519",
#   "PlayerID": 22519,
#   "Name": "Nick Eubanks",
#   "Team": "DAL",
#   "Position": "TE",
#   "AverageDraftPosition": 2037.2,
#   "AverageDraftPositionPPR": 2024.8,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22536",
#   "PlayerID": 22536,
#   "Name": "C.J. Marable",
#   "Team": "CHI",
#   "Position": "RB",
#   "AverageDraftPosition": 2038.3,
#   "AverageDraftPositionPPR": 2025.9,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22537",
#   "PlayerID": 22537,
#   "Name": "Trey Ragas",
#   "Team": "LV",
#   "Position": "RB",
#   "AverageDraftPosition": 2039.4,
#   "AverageDraftPositionPPR": 2027.0,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22617",
#   "PlayerID": 22617,
#   "Name": "Marlon Williams",
#   "Team": "HOU",
#   "Position": "WR",
#   "AverageDraftPosition": 2043.9,
#   "AverageDraftPositionPPR": 2031.5,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22638",
#   "PlayerID": 22638,
#   "Name": "Dillon Stoner",
#   "Team": "LV",
#   "Position": "WR",
#   "AverageDraftPosition": 2045.1,
#   "AverageDraftPositionPPR": 2032.7,
#   "ByeWeek": 8,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22652",
#   "PlayerID": 22652,
#   "Name": "Josh Johnson",
#   "Team": "SEA",
#   "Position": "RB",
#   "AverageDraftPosition": 2046.2,
#   "AverageDraftPositionPPR": 2033.8,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22658",
#   "PlayerID": 22658,
#   "Name": "Shaun Beyer",
#   "Team": "DEN",
#   "Position": "TE",
#   "AverageDraftPosition": 2047.3,
#   "AverageDraftPositionPPR": 2034.9,
#   "ByeWeek": 11,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22665",
#   "PlayerID": 22665,
#   "Name": "Pro Wells",
#   "Team": "CIN",
#   "Position": "TE",
#   "AverageDraftPosition": 2048.4,
#   "AverageDraftPositionPPR": 2036.0,
#   "ByeWeek": 10,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22674",
#   "PlayerID": 22674,
#   "Name": "Deon Jackson",
#   "Team": "IND",
#   "Position": "RB",
#   "AverageDraftPosition": 2049.6,
#   "AverageDraftPositionPPR": 2037.2,
#   "ByeWeek": 14,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22701",
#   "PlayerID": 22701,
#   "Name": "Darius Clark",
#   "Team": "CAR",
#   "Position": "RB",
#   "AverageDraftPosition": 2063.1,
#   "AverageDraftPositionPPR": 2050.7,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22717",
#   "PlayerID": 22717,
#   "Name": "Jose Borregales",
#   "Team": "TB",
#   "Position": "K",
#   "AverageDraftPosition": 2072.1,
#   "AverageDraftPositionPPR": 2059.7,
#   "ByeWeek": 9,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "22863",
#   "PlayerID": 22863,
#   "Name": "Riley Patterson",
#   "Team": "MIN",
#   "Position": "K",
#   "AverageDraftPosition": 2160.1,
#   "AverageDraftPositionPPR": 2147.7,
#   "ByeWeek": 7,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "23075",
#   "PlayerID": 23075,
#   "Name": "Chris Naggar",
#   "Team": "NYJ",
#   "Position": "K",
#   "AverageDraftPosition": 2239.1,
#   "AverageDraftPositionPPR": 2226.7,
#   "ByeWeek": 6,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "23080",
#   "PlayerID": 23080,
#   "Name": "Quinn Nordin",
#   "Team": "NE",
#   "Position": "K",
#   "AverageDraftPosition": 2240.2,
#   "AverageDraftPositionPPR": 2227.8,
#   "ByeWeek": 14,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "20779",
#   "PlayerID": 20779,
#   "Name": "Will Grier",
#   "Team": "CAR",
#   "Position": "QB",
#   "AverageDraftPosition": 2243.6,
#   "AverageDraftPositionPPR": 2231.2,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": 0.0,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  },
#  {
#   "FantasyPlayerKey": "21115",
#   "PlayerID": 21115,
#   "Name": "Juwann Winfree",
#   "Team": "GB",
#   "Position": "WR",
#   "AverageDraftPosition": 2244.7,
#   "AverageDraftPositionPPR": 2232.3,
#   "ByeWeek": 13,
#   "LastSeasonFantasyPoints": 0.0,
#   "ProjectedFantasyPoints": -3.4,
#   "AuctionValue": 0,
#   "AuctionValuePPR": 0,
#   "AverageDraftPositionIDP": null,
#   "AverageDraftPositionRookie": null,
#   "AverageDraftPositionDynasty": null,
#   "AverageDraftPosition2QB": null
#  }
# ]

# %%
#Create Data Frame from API results (includes all fields)
df= pd.read_json(f"https://api.sportsdata.io/v3/nfl/stats/json/FantasyPlayers?key=4339cb9aa27441699f1883848f498899")

# %%
#BY
#Create Data Frame that will be used to create a table of just positions that wil be used for site drop down
position = df["Position"].unique()
position_dropdown_df = pd.DataFrame(position).rename(columns={0:'Position'})
position_dropdown_df
# position_df =pd.DataFrame(position)
# Out:
#   Position
# 0       RB
# 1       WR
# 2       TE
# 3       QB
# 4      DEF
# 5        K

# %%
#BY
#Create Data Frame that will be used to create table of all stats for each posiiton (5 total)
#RB

RB = df.drop(columns =["FantasyPlayerKey", "PlayerID","AuctionValue","AuctionValuePPR","AverageDraftPositionIDP","AverageDraftPositionRookie","AverageDraftPositionDynasty","AverageDraftPosition2QB"])
RB_df = RB.loc[RB["Position"]=="RB"]
RB_df
# # RB_df = df["Position"].u
# oc[concatenated_df["3_TECH_ORG_CORRECT"]=="1"]nique()

# tech_mental_health = concatenated_df.loc[concatenated_df["3_TECH_ORG_CORRECT"]=="1"]
# tech_mental_health

# position_df = pd.DataFrame(position).rename(columns={0:'Position'})
# position_df

# "Team","Position","AverageDraftPosition", "AverageDraftPositionPPR", "ByeWeek", "LastSeasonFantasyPoints", "ProjectedFantasyPoints"\
#                 from "ADP_Data"\
# Out:
#                     Name Team Position  AverageDraftPosition  \
# 0    Christian McCaffrey  CAR       RB                   1.7
# 1            Dalvin Cook  MIN       RB                   3.2
# 2          Derrick Henry  TEN       RB                   3.4
# 3           Alvin Kamara   NO       RB                   5.5
# 4        Ezekiel Elliott  DAL       RB                   6.6
# ..                   ...  ...      ...                   ...
# 856         C.J. Marable  CHI       RB                2038.3
# 857           Trey Ragas   LV       RB                2039.4
# 860         Josh Johnson  SEA       RB                2046.2
# 863         Deon Jackson  IND       RB                2049.6
# 864         Darius Clark  CAR       RB                2063.1
#
#      AverageDraftPositionPPR  ByeWeek  LastSeasonFantasyPoints  \
# 0                        1.7     13.0                     82.8
# 1                        3.2      7.0                    331.4
# 2                        4.6     13.0                    354.3
# 3                        5.3      6.0                    332.5
# 4                        6.9      7.0                    193.7
# ..                       ...      ...                      ...
# 856                   2025.9     10.0                      0.0
# 857                   2027.0      8.0                      0.0
# 860                   2033.8      9.0                      0.0
# 863                   2037.2     14.0                      0.0
# 864                   2050.7     13.0                      0.0
#
#      ProjectedFantasyPoints
# 0                     308.7
# 1                     298.0
# 2                     303.9
# 3                     246.7
# 4                     254.4
# ..                      ...
# 856                     0.0
# 857                     0.0
# 860                     0.0
# 863                     0.0
# 864                     0.0
#
# [202 rows x 8 columns]

# %%
#BY
#Create Data Frame that will be used to create table of all stats for each posiiton (5 total)
#WR 

WR = df.drop(columns =["FantasyPlayerKey", "PlayerID","AuctionValue","AuctionValuePPR","AverageDraftPositionIDP","AverageDraftPositionRookie","AverageDraftPositionDynasty","AverageDraftPosition2QB"])
WR_df = WR.loc[WR["Position"]=="WR"]
WR_df
# Out:
#                 Name Team Position  AverageDraftPosition  \
# 8        Tyreek Hill   KC       WR                  10.2
# 12     Davante Adams   GB       WR                  14.7
# 14      Stefon Diggs  BUF       WR                  15.8
# 17        DK Metcalf  SEA       WR                  19.6
# 20   DeAndre Hopkins  ARI       WR                  22.9
# ..               ...  ...      ...                   ...
# 831  Binjimen Victor  BAL       WR                1772.1
# 833     Aaron Fuller  SEA       WR                1774.3
# 858  Marlon Williams  HOU       WR                2043.9
# 859    Dillon Stoner   LV       WR                2045.1
# 870   Juwann Winfree   GB       WR                2244.7
#
#      AverageDraftPositionPPR  ByeWeek  LastSeasonFantasyPoints  \
# 8                       10.8     12.0                    272.9
# 12                      15.2     13.0                    274.6
# 14                      13.6      7.0                    227.4
# 17                      23.3      9.0                    212.4
# 20                      18.0     12.0                    194.9
# ..                       ...      ...                      ...
# 831                   1759.7      8.0                      0.0
# 833                   1761.9      9.0                      0.0
# 858                   2031.5     10.0                      0.0
# 859                   2032.7      8.0                      0.0
# 870                   2232.3     13.0                      0.0
#
#      ProjectedFantasyPoints
# 8                     241.4
# 12                    222.3
# 14                    193.5
# 17                    214.8
# 20                    203.3
# ..                      ...
# 831                     0.0
# 833                     0.0
# 858                     0.0
# 859                     0.0
# 870                    -3.4
#
# [312 rows x 8 columns]

# %%
#BY
#Create Data Frame that will be used to create table of all stats for each posiiton (5 total)
#TE

TE = df.drop(columns =["FantasyPlayerKey", "PlayerID","AuctionValue","AuctionValuePPR","AverageDraftPositionIDP","AverageDraftPositionRookie","AverageDraftPositionDynasty","AverageDraftPosition2QB"])
TE_df = TE.loc[TE["Position"]=="TE"]
TE_df
# Out:
#                Name Team Position  AverageDraftPosition  \
# 9      Travis Kelce   KC       TE                  11.1
# 27    Darren Waller   LV       TE                  31.4
# 31    George Kittle   SF       TE                  34.6
# 50       Kyle Pitts  ATL       TE                  55.0
# 54     Mark Andrews  BAL       TE                  59.7
# ..              ...  ...      ...                   ...
# 853  Quintin Morris  BUF       TE                2034.9
# 854    Matt Bushman   LV       TE                2036.0
# 855    Nick Eubanks  DAL       TE                2037.2
# 861     Shaun Beyer  DEN       TE                2047.3
# 862       Pro Wells  CIN       TE                2048.4
#
#      AverageDraftPositionPPR  ByeWeek  LastSeasonFantasyPoints  \
# 9                       10.9     12.0                    234.4
# 27                      25.3      8.0                    193.6
# 31                      32.8      6.0                     87.0
# 50                      46.0      6.0                      0.0
# 54                      59.2      8.0                    126.4
# ..                       ...      ...                      ...
# 853                   2022.5      7.0                      0.0
# 854                   2023.6      8.0                      0.0
# 855                   2024.8      7.0                      0.0
# 861                   2034.9     11.0                      0.0
# 862                   2036.0     10.0                      0.0
#
#      ProjectedFantasyPoints
# 9                     216.0
# 27                    172.3
# 31                    169.8
# 50                    135.8
# 54                    148.2
# ..                      ...
# 853                     0.0
# 854                     0.0
# 855                     0.0
# 861                     0.0
# 862                     0.0
#
# [165 rows x 8 columns]

# %%
#BY
#Create Data Frame that will be used to create table of all stats for each posiiton (5 total)
#QB

QB = df.drop(columns =["FantasyPlayerKey", "PlayerID","AuctionValue","AuctionValuePPR","AverageDraftPositionIDP","AverageDraftPositionRookie","AverageDraftPositionDynasty","AverageDraftPosition2QB"])
QB_df = QB.loc[QB["Position"]=="QB"]
QB_df
# Out:
#                 Name  Team Position  AverageDraftPosition  \
# 15   Patrick Mahomes    KC       QB                  16.1
# 32        Josh Allen   BUF       QB                  36.2
# 38      Kyler Murray   ARI       QB                  43.0
# 43      Dak Prescott   DAL       QB                  48.5
# 46     Lamar Jackson   BAL       QB                  51.0
# ..               ...   ...      ...                   ...
# 841    Bryce Perkins   LAR       QB                1783.4
# 842    Cole McDonald  None       QB                1784.5
# 851      Ben DiNucci   DAL       QB                1949.2
# 852    Tommy Stevens  None       QB                1954.8
# 869       Will Grier   CAR       QB                2243.6
#
#      AverageDraftPositionPPR  ByeWeek  LastSeasonFantasyPoints  \
# 15                      24.5     12.0                    422.3
# 32                      42.3      7.0                    445.6
# 38                      50.0     12.0                    427.2
# 43                      60.2      7.0                    151.9
# 46                      56.2      8.0                    375.4
# ..                       ...      ...                      ...
# 841                   1771.0     11.0                      0.0
# 842                   1772.1      NaN                      0.0
# 851                   1936.8      7.0                      8.9
# 852                   1942.4      NaN                      3.1
# 869                   2231.2     13.0                      0.0
#
#      ProjectedFantasyPoints
# 15                    449.0
# 32                    432.8
# 38                    407.2
# 43                    402.5
# 46                    398.3
# ..                      ...
# 841                     0.0
# 842                     0.0
# 851                     0.0
# 852                     0.0
# 869                     0.0
#
# [113 rows x 8 columns]

# %%
DEF = df.drop(columns =["FantasyPlayerKey", "PlayerID","AuctionValue","AuctionValuePPR","AverageDraftPositionIDP","AverageDraftPositionRookie","AverageDraftPositionDynasty","AverageDraftPosition2QB"])
DEF_df = DEF.loc[DEF["Position"]=="DEF"]
DEF_df
# Out:
#                          Name Team Position  AverageDraftPosition  \
# 107       Pittsburgh Steelers  PIT      DEF                 118.0
# 114          Baltimore Ravens  BAL      DEF                 126.3
# 118          Los Angeles Rams  LAR      DEF                 127.6
# 122  Washington Football Team  WAS      DEF                 133.3
# 128      Tampa Bay Buccaneers   TB      DEF                 140.2
# 135        Indianapolis Colts  IND      DEF                 149.1
# 137           New York Giants  NYG      DEF                 150.6
# 146          Seattle Seahawks  SEA      DEF                 156.0
# 147       San Francisco 49ers   SF      DEF                 156.6
# 148            Dallas Cowboys  DAL      DEF                 157.4
# 154             Buffalo Bills  BUF      DEF                 162.4
# 161      New England Patriots   NE      DEF                 168.2
# 177            Miami Dolphins  MIA      DEF                 178.7
# 185          Cleveland Browns  CLE      DEF                 182.2
# 189         Carolina Panthers  CAR      DEF                 182.7
# 191         Minnesota Vikings  MIN      DEF                 183.2
# 203         Arizona Cardinals  ARI      DEF                 187.0
# 210         Green Bay Packers   GB      DEF                 189.5
# 211            Denver Broncos  DEN      DEF                 189.8
# 214        Kansas City Chiefs   KC      DEF                 193.5
# 218      Los Angeles Chargers  LAC      DEF                 200.3
# 219             Chicago Bears  CHI      DEF                 200.9
# 220       Philadelphia Eagles  PHI      DEF                 201.9
# 221        New Orleans Saints   NO      DEF                 202.1
# 222             New York Jets  NYJ      DEF                 204.2
# 224      Jacksonville Jaguars  JAX      DEF                 205.3
# 225          Tennessee Titans  TEN      DEF                 206.4
# 229             Detroit Lions  DET      DEF                 209.8
# 232            Houston Texans  HOU      DEF                 210.9
# 234        Cincinnati Bengals  CIN      DEF                 212.1
# 236         Las Vegas Raiders   LV      DEF                 213.2
# 239           Atlanta Falcons  ATL      DEF                 215.4
#
#      AverageDraftPositionPPR  ByeWeek  LastSeasonFantasyPoints  \
# 107                    122.6      7.0                    169.2
# 114                    156.2      8.0                    161.3
# 118                    130.8     11.0                    168.1
# 122                    140.9      9.0                    143.3
# 128                    134.7      9.0                    132.0
# 135                    150.1     14.0                    170.3
# 137                    192.2     10.0                    116.2
# 146                    171.1      9.0                    116.2
# 147                    162.8      6.0                     99.3
# 148                    177.1      7.0                     88.0
# 154                    183.8      7.0                    133.1
# 161                    166.8     14.0                    117.3
# 177                    181.0     14.0                    156.8
# 185                    173.8     13.0                    106.0
# 189                    190.3     13.0                    109.4
# 191                    184.0      7.0                     64.3
# 203                    188.8     12.0                    120.7
# 210                    192.0     13.0                    106.0
# 211                    192.7     11.0                     83.5
# 214                    202.4     12.0                    124.1
# 218                    203.8      7.0                     81.2
# 219                    200.2     10.0                    101.5
# 220                    199.7     14.0                    116.2
# 221                    183.8      6.0                    137.6
# 222                    200.8      6.0                     73.3
# 224                    196.7      7.0                     58.7
# 225                    138.0     13.0                     79.0
# 229                    203.0      9.0                     30.5
# 232                    204.2     10.0                     54.1
# 234                    205.3     10.0                     50.8
# 236                    206.4      8.0                     44.0
# 239                    192.5      6.0                     81.2
#
#      ProjectedFantasyPoints
# 107                   129.7
# 114                   121.8
# 118                   115.1
# 122                   100.4
# 128                   107.2
# 135                   116.2
# 137                    91.4
# 146                   104.9
# 147                   118.4
# 148                    97.0
# 154                   110.5
# 161                   117.3
# 177                    93.6
# 185                   100.4
# 189                    95.9
# 191                   103.8
# 203                    93.6
# 210                   103.8
# 211                   104.9
# 214                   119.6
# 218                   101.5
# 219                   103.8
# 220                   108.3
# 221                   119.6
# 222                   100.4
# 224                    99.3
# 225                    98.1
# 229                    94.8
# 232                    93.6
# 234                    92.5
# 236                    92.5
# 239                    89.1

# %%
K = df.drop(columns =["FantasyPlayerKey", "PlayerID","AuctionValue","AuctionValuePPR","AverageDraftPositionIDP","AverageDraftPositionRookie","AverageDraftPositionDynasty","AverageDraftPosition2QB"])
K_df = DEF.loc[K["Position"]=="K"]
K_df
# Out:
#                     Name  Team Position  AverageDraftPosition  \
# 149      Harrison Butker    KC        K                 157.8
# 151         Younghoe Koo   ATL        K                 159.0
# 156        Justin Tucker   BAL        K                 163.1
# 157        Greg Zuerlein   DAL        K                 163.9
# 158  Rodrigo Blankenship   IND        K                 166.0
# 163          Ryan Succop    TB        K                 170.3
# 168        Jason Sanders   MIA        K                 173.9
# 170             Wil Lutz    NO        K                 174.3
# 176          Matt Prater   ARI        K                 178.3
# 178           Tyler Bass   BUF        K                 178.8
# 189       Daniel Carlson    LV        K                 183.1
# 209             Matt Gay   LAR        K                 190.9
# 211          Jason Myers   SEA        K                 191.6
# 212         Robbie Gould    SF        K                 191.9
# 217         Mason Crosby    GB        K                 194.9
# 220      Brandon McManus   DEN        K                 199.9
# 478      Michael Badgley   LAC        K                 482.8
# 482         Cairo Santos   CHI        K                 487.3
# 484          Graham Gano   NYG        K                 489.6
# 485        Chris Boswell   PIT        K                 490.7
# 489            Joey Slye   CAR        K                 495.2
# 490       Dustin Hopkins   WAS        K                 496.3
# 492          Cody Parkey   CLE        K                 498.6
# 494          Greg Joseph   MIN        K                 500.8
# 497           Josh Lambo   JAX        K                 504.2
# 500            Nick Folk    NE        K                 507.6
# 501     Ka'imi Fairbairn   HOU        K                 508.7
# 507       Evan McPherson   CIN        K                 515.5
# 509         Jake Elliott   PHI        K                 517.8
# 511           Sam Ficken   NYJ        K                 520.0
# 514        Randy Bullock   DET        K                 523.4
# 519        Tucker McCann   TEN        K                 529.0
# 545       Austin Seibert   CIN        K                 558.4
# 570        Aldrick Rosas   JAX        K                 586.6
# 645        Samuel Sloman   PIT        K                 671.2
# 660     Chase McLaughlin   CLE        K                 688.1
# 663       Matthew Wright   DET        K                 691.5
# 713        Blake Haubeil   TEN        K                 747.9
# 768       Roberto Aguayo  None        K                1076.1
# 772            Jon Brown  None        K                1175.4
# 796         Eddy Piñeiro   IND        K                1457.4
# 819          Elliott Fry  None        K                1676.2
# 850     Austin MacGinnis   LAR        K                1939.0
# 865      Jose Borregales    TB        K                2068.8
# 866      Riley Patterson   MIN        K                2156.7
# 867         Chris Naggar   NYJ        K                2235.7
# 868         Quinn Nordin    NE        K                2236.8
#
#      AverageDraftPositionPPR  ByeWeek  LastSeasonFantasyPoints  \
# 149                    163.9     12.0                    147.8
# 151                    161.3      6.0                    180.5
# 156                    157.1      8.0                    153.4
# 157                    168.9      7.0                    159.0
# 158                    168.7     14.0                    159.0
# 163                    172.4      9.0                    155.7
# 168                    168.4     14.0                    180.5
# 170                    174.5      6.0                    144.4
# 176                    178.9     12.0                    127.5
# 178                    177.7      7.0                    168.1
# 189                    194.7      8.0                    171.5
# 209                    190.6     11.0                     67.7
# 211                    199.0      9.0                    141.0
# 212                    185.2      6.0                    109.4
# 217                    195.0     13.0                    129.7
# 220                    531.3     11.0                    144.4
# 478                    202.3      7.0                    126.3
# 482                    526.8     10.0                    146.6
# 484                    527.9     10.0                    139.9
# 485                    529.0      7.0                    104.9
# 489                    200.8     13.0                    137.6
# 490                    533.5      9.0                    129.7
# 492                    534.7     13.0                    112.8
# 494                    536.9      7.0                      0.0
# 497                    540.3      7.0                     30.5
# 500                    542.6     14.0                    126.3
# 501                    544.8     10.0                    142.1
# 507                    550.5     10.0                      0.0
# 509                    551.6     14.0                     79.0
# 511                    553.8      6.0                     59.8
# 514                    559.5      9.0                    104.9
# 519                    567.4     13.0                      0.0
# 545                    591.1     10.0                     29.3
# 570                    620.4      7.0                     44.0
# 645                    699.4      7.0                     59.8
# 660                    738.8     13.0                     21.4
# 663                    746.7      9.0                     21.4
# 713                    759.1     13.0                      0.0
# 768                   1067.1      NaN                    110.5
# 772                   1166.4      NaN                      5.1
# 796                   1448.4     14.0                    112.8
# 819                   1667.2      NaN                      5.1
# 850                   1930.0     11.0                      0.0
# 865                   2059.7      9.0                      0.0
# 866                   2147.7      7.0                      0.0
# 867                   2226.7      6.0                      0.0
# 868                   2227.8     14.0                      0.0
#
#      ProjectedFantasyPoints
# 149                   156.5
# 151                   150.0
# 156                   157.6
# 157                   154.0
# 158                   148.1
# 163                   151.2
# 168                   150.4
# 170                   145.4
# 176                   142.2
# 178                   155.4
# 189                   145.2
# 209                   145.2
# 211                   146.9
# 212                   146.6
# 217                   140.4
# 220                   137.4
# 478                   142.2
# 482                   138.3
# 484                   138.2
# 485                   137.6
# 489                   136.3
# 490                   136.0
# 492                   134.8
# 494                   134.2
# 497                   130.8
# 500                   129.3
# 501                   128.4
# 507                   124.8
# 509                   123.3
# 511                   120.6
# 514                   116.0
# 519                   110.5
# 545                    86.7
# 570                    65.4
# 645                    29.9
# 660                    23.9
# 663                    22.6
# 713                    13.5
# 768                     0.0
# 772                     0.0
# 796                     0.0
# 819                     0.0
# 850                     0.0
# 865                     0.0
# 866                     0.0
# 867                     0.0
# 868                     0.0

# %%
#Load DF into Database NFL_Fantasy_Data
#Create connection to Postgres
connection_string = "postgres:postgres@localhost:5432/NFL_Fantasy_Data"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Create ADP table and load into DB
df.to_sql(name='ADP_Data', con=engine, if_exists='append', index=False)

# %%
#BY
#Create Dropdown table and load into DB
position_dropdown_df.to_sql(name='Position_dropdown', con=engine, if_exists='append', index=False)

# %%
#BY
#Create  table and load into DB
RB_df.to_sql(name='RB_Data', con=engine, if_exists='append', index=False)

# %%
#BY
#Create  table and load into DB
WR_df.to_sql(name='WR_Data', con=engine, if_exists='append', index=False)

# %%
#BY
#Create  table and load into DB
TE_df.to_sql(name='TE_Data', con=engine, if_exists='append', index=False)

# %%
#BY
#Create  table and load into DB
QB_df.to_sql(name='QB_Data', con=engine, if_exists='append', index=False)

# %%
#BY
#Create  table and load into DB
DEF_df.to_sql(name='DEF_Data', con=engine, if_exists='append', index=False)

# %%
#BY
#Create  table and load into DB
K_df.to_sql(name='K_Data', con=engine, if_exists='append', index=False)

# %%
#confirm data succesfully loaded in

pd.read_sql_query('select * from "ADP_Data"', con=engine)
# Out:
#     FantasyPlayerKey  PlayerID                 Name Team Position  \
# 0              18877     18877  Christian McCaffrey  CAR       RB
# 1              18872     18872          Dalvin Cook  MIN       RB
# 2              17959     17959        Derrick Henry  TEN       RB
# 3              18878     18878         Alvin Kamara   NO       RB
# 4              17923     17923      Ezekiel Elliott  DAL       RB
# ..               ...       ...                  ...  ...      ...
# 866            22863     22863      Riley Patterson  MIN        K
# 867            23075     23075         Chris Naggar  NYJ        K
# 868            23080     23080         Quinn Nordin   NE        K
# 869            20779     20779           Will Grier  CAR       QB
# 870            21115     21115       Juwann Winfree   GB       WR
#
#      AverageDraftPosition  AverageDraftPositionPPR  ByeWeek  \
# 0                     1.7                      1.7     13.0
# 1                     3.2                      3.2      7.0
# 2                     3.4                      4.6     13.0
# 3                     5.5                      5.3      6.0
# 4                     6.6                      6.9      7.0
# ..                    ...                      ...      ...
# 866                2156.7                   2147.7      7.0
# 867                2235.7                   2226.7      6.0
# 868                2236.8                   2227.8     14.0
# 869                2240.2                   2231.2     13.0
# 870                2241.3                   2232.3     13.0
#
#      LastSeasonFantasyPoints  ProjectedFantasyPoints  AuctionValue  \
# 0                       82.8                   309.4            76
# 1                      331.4                   298.0            71
# 2                      354.3                   303.9            71
# 3                      332.5                   246.7            58
# 4                      193.7                   254.4            59
# ..                       ...                     ...           ...
# 866                      0.0                     0.0             0
# 867                      0.0                     0.0             0
# 868                      0.0                     0.0             0
# 869                      0.0                     0.0             0
# 870                      0.0                    -3.4             0
#
#      AuctionValuePPR  AverageDraftPositionIDP AverageDraftPositionRookie  \
# 0                 77                      4.0                       None
# 1                 70                     19.0                       None
# 2                 61                     46.0                       None
# 3                 59                      3.0                       None
# 4                 58                      8.0                       None
# ..               ...                      ...                        ...
# 866                0                      NaN                       None
# 867                0                      NaN                       None
# 868                0                      NaN                       None
# 869                0                      NaN                       None
# 870                0                      NaN                       None
#
#     AverageDraftPositionDynasty AverageDraftPosition2QB
# 0                          None                    None
# 1                          None                    None
# 2                          None                    None
# 3                          None                    None
# 4                          None                    None
# ..                          ...                     ...
# 866                        None                    None
# 867                        None                    None
# 868                        None                    None
# 869                        None                    None
# 870                        None                    None
#
# [871 rows x 16 columns]

# %%
# Query to find the unique positions of each player; to be used for Landing Page Dropdown
pd.read_sql_query('Select distinct "Position"from "ADP_Data";', con=engine)
# Out:
#   Position
# 0      DEF
# 1       RB
# 2       QB
# 3        K
# 4       WR
# 5       TE

# %%
#Note: We are creating views and displaying stats based on the Draft Pick method of selection instead of auction method. We used all position values instead of looking at individual position values exclusively (IDP)
# Query to find the stats per each position once drop down in Landing Page is selected. 
# Want this sorted by ADP Ranking; replicate this query for each position  

#DEF

wr_query = """
Select "Name", "Team","Position","AverageDraftPosition", "AverageDraftPositionPPR", "ByeWeek", "LastSeasonFantasyPoints", "ProjectedFantasyPoints"\
                from "ADP_Data"\
                where "Position"= 'WR' order by "AverageDraftPosition" asc;
"""

pd.read_sql_query(wr_query, con=engine)
# Out:
#                 Name Team Position  AverageDraftPosition  \
# 0        Tyreek Hill   KC       WR                  10.3
# 1      Davante Adams   GB       WR                  14.8
# 2       Stefon Diggs  BUF       WR                  15.7
# 3         DK Metcalf  SEA       WR                  19.4
# 4    DeAndre Hopkins  ARI       WR                  22.9
# ..               ...  ...      ...                   ...
# 307  Binjimen Victor  BAL       WR                1768.7
# 308     Aaron Fuller  SEA       WR                1771.0
# 309  Marlon Williams  HOU       WR                2040.6
# 310    Dillon Stoner   LV       WR                2041.7
# 311   Juwann Winfree   GB       WR                2241.3
#
#      AverageDraftPositionPPR  ByeWeek  LastSeasonFantasyPoints  \
# 0                       10.7     12.0                    272.9
# 1                       15.1     13.0                    274.6
# 2                       13.5      7.0                    227.4
# 3                       23.3      9.0                    212.4
# 4                       17.9     12.0                    194.9
# ..                       ...      ...                      ...
# 307                   1759.7      8.0                      0.0
# 308                   1761.9      9.0                      0.0
# 309                   2031.5     10.0                      0.0
# 310                   2032.7      8.0                      0.0
# 311                   2232.3     13.0                      0.0
#
#      ProjectedFantasyPoints
# 0                     241.4
# 1                     222.3
# 2                     193.5
# 3                     214.8
# 4                     203.3
# ..                      ...
# 307                     0.0
# 308                     0.0
# 309                     0.0
# 310                     0.0
# 311                    -3.4
#
# [312 rows x 8 columns]

# %%
#Create connection to Postgres
connection_string = "postgres:postgres@localhost:5432/NFL_Fantasy_Data"
engine = create_engine(f'postgresql://{connection_string}')

# %%
Base = automap_base()

# %%
Base.prepare(engine, reflect= True)

# %%
Base.classes.keys()
# Out:
# ['ADP_Data',
#  'Position_dropdown',
#  'RB_Data',
#  'WR_Data',
#  'TE_Data',
#  'QB_Data',
#  'DEF_Data',
#  'K_Data']
